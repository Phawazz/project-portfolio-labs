# %%
import pandas as pd

df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
chest_pain = df.groupby('ChestPainType')

# %%
chest_pain

# %%
for cp, cp_df in chest_pain:
    print(cp)
    print(cp_df)
# Out:
# ASY
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 3     48   F           ASY        138          214          0     Normal
# 8     37   M           ASY        140          207          0     Normal
# 13    49   M           ASY        140          234          0     Normal
# 16    38   M           ASY        110          196          0     Normal
# 18    60   M           ASY        100          248          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 909   63   F           ASY        124          197          0     Normal
# 911   59   M           ASY        164          176          1        LVH
# 912   57   F           ASY        140          241          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
chest_pain.get_group('ASY')
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 3     48   F           ASY        138          214          0     Normal
# 8     37   M           ASY        140          207          0     Normal
# 13    49   M           ASY        140          234          0     Normal
# 16    38   M           ASY        110          196          0     Normal
# 18    60   M           ASY        100          248          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 909   63   F           ASY        124          197          0     Normal
# 911   59   M           ASY        164          176          1        LVH
# 912   57   F           ASY        140          241          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
chest_pain.max()
# Out:
#                Age Sex  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# ChestPainType
# ASY             77   M        200          603          1         ST    186
# ATA             74   M        192          468          1         ST    202
# NAP             76   M        200          564          1         ST    194
# TA              74   M        178          308          1         ST    190
#
#               ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ChestPainType
# ASY                        Y      6.2       Up             1
# ATA                        Y      3.0       Up             1
# NAP                        Y      3.6       Up             1
# TA                         Y      4.2       Up             1

# %%
chest_pain.min()
# Out:
#                Age Sex  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# ChestPainType
# ASY             31   F         80            0          0        LVH     60
# ATA             28   F         98            0          0        LVH     93
# NAP             33   F          0            0          0        LVH     70
# TA              30   F         95            0          0        LVH     98
#
#               ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ChestPainType
# ASY                        N     -2.6     Down             0
# ATA                        N      0.0     Down             0
# NAP                        N     -2.0     Down             0
# TA                         N     -0.8     Down             0

# %%
chest_pain.describe().T
# Out:
# ChestPainType              ASY         ATA         NAP          TA
# Age          count  496.000000  173.000000  203.000000   46.000000
#              mean    54.959677   49.242775   53.310345   54.826087
#              std      8.763468    9.259754    9.608023   11.449026
#              min     31.000000   28.000000   33.000000   30.000000
#              25%     49.000000   42.000000   47.000000   46.250000
#              50%     56.000000   51.000000   53.000000   59.000000
#              75%     61.000000   55.000000   60.000000   62.750000
#              max     77.000000   74.000000   76.000000   74.000000
# RestingBP    count  496.000000  173.000000  203.000000   46.000000
#              mean   133.229839  130.624277  130.960591  136.413043
#              std     18.580961   16.861711   19.412878   19.059644
#              min     80.000000   98.000000    0.000000   95.000000
#              25%    120.000000  120.000000  120.000000  120.000000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16, 15))

chest_pain.plot()

plt.show()
